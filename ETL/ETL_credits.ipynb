# %% [markdown]
# # <h1 align=center> **ETL - DATASET CREDITS** </h1>
# <h1 align=center> (Extract, Transform, Load) </h1>

# %% [markdown]
# Como fase previa a la aplicación del ETL, se realizará la importación de librerías que serán de utilidad en el desarrollo del proceso, las cuales son:

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from collections import Counter
from scipy.spatial import distance
import json
import ast
import os
import re

# %% [markdown]
# # <h1 align=left>**`Extract`**</h1>

# %%
df_credits = pd.read_csv("..\Data\credits.csv")

# %%
df_movies = pd.read_csv("..\Data\movies_dataset_ETL.csv")

# %% [markdown]
# # <h1 align=left>**`Transform`**</h1>

# %% [markdown]
# Se consulta los datos que contiene el DataFrame, para identificar su estructura y la información que contiene y se procede a reorganizar las variables para que el **`id`** quede en primera posición.

# %%
df_credits = df_credits.reindex(columns=['id',
                                        'crew',
                                        'cast'])                                        
df_credits

# %% [markdown]
# **1.** Se eliminan las comillas simples dentro de comillas dobles.

# %%
def remove_single_quotes_within_double_quotes(text):
    pattern = r'"([^"]*?\'[^"]*?)"'
    matches = re.findall(pattern, text)
    for match in matches:
        text = text.replace(match, match.replace("'", " "))
    return text

# %% [markdown]
# **2.** Aplicar la función remove_single_quotes_within_double_quotes() al DataFrame.

# %%
df_credits["crew"] = df_credits["crew"].apply(remove_single_quotes_within_double_quotes)

# %% [markdown]
# **3.** Se realiza limpieza a la variable **`id`** y en general al DataFrame, así:

# %% [markdown]
# + Convertimos la columna "id" a entero
#
# + Eliminar duplicados en la columna "id"
#
# + Reorganizar las columnas del dataframe
#
# + Reemplazar caracteres ' por " en la columna: "crew"
#
# + Reemplazar texto "None" por "" (espacios vacíos) en la columna "crew" para solucionar errores del formato Json
#
# + Organizar columna por "id" (ascendente)

# %%
df_credits = df_credits.astype({"id": "int64"})

df_credits = df_credits.drop_duplicates(subset=["id"])

df_credits = df_credits[["id", "cast", "crew"]]

df_credits["crew"] = df_credits["crew"].str.replace("'", "\"", case=False, regex=False)

df_credits["crew"] = df_credits["crew"].str.replace("None", "\"\"", case=False, regex=False)

df_credits = df_credits.sort_values(["id"], ignore_index=True)

# %% [markdown]
# **4.** Se crea la función **`extract_director_name`** con la librería **_`json`_** la cual extrae de la variable **`crew`** todos los nombres de las personas asignadas con trabajo 'Director' y la fórmula se aplica en una nueva variable llamada **`drection_name`**.

# %%
def extract_director_name(crew_json):
    try:
        crew_list = json.loads(crew_json)
        director_names = [entry['name'] for entry in crew_list if entry['job'] == 'Director']
        return director_names[0] if len(director_names)== 1 else director_names
    except (json.JSONDecodeError, TypeError):
        return None

df_credits["direction_name"] = df_credits["crew"].apply(extract_director_name)

# %% [markdown]
# **5.** Se consulta el DataFrame para validar la correcta aplicación de la fórmula.

# %%
df_credits.head(3)
# Out:
#    id                                               cast  \
# 0   2  [{'cast_id': 3, 'character': 'Taisto Olavi Kas...
# 1   3  [{'cast_id': 5, 'character': 'Nikander', 'cred...
# 2   5  [{'cast_id': 42, 'character': 'Ted the Bellhop...
#
#                                                 crew  \
# 0  [{"credit_id": "52fe420dc3a36847f800001f", "de...
# 1  [{"credit_id": "52fe420dc3a36847f8000077", "de...
# 2  [{"credit_id": "52fe420dc3a36847f800011b", "de...
#
#                                       direction_name
# 0                                     Aki Kaurismäki
# 1                                     Aki Kaurismäki
# 2  [Allison Anders, Alexandre Rockwell, Robert Ro...

# %% [markdown]
# **6.** Se unen los dos DataFrames importados a través de la función **`.merge`**.

# %%
df_movies_crew = pd.merge(df_movies, df_credits[['id', 'direction_name']], on='id', how='left')
df_movies_crew.head(10)
# Out:
#    Unnamed: 0  id                                title  \
# 0       45463   0                         Midnight Man
# 1       45464   1  Mardock Scramble: The Third Exhaust
# 2        4342   2                                Ariel
# 3       12947   3                  Shadows in Paradise
# 4       45465   4                     Avalanche Sharks
# 5          17   5                           Four Rooms
# 6         474   6                       Judgment Night
# 7         256  11                            Star Wars
# 8        6232  12                         Finding Nemo
# 9         351  13                         Forrest Gump
#
#                                             overview  \
# 0                                                  0
# 1                                                  0
# 2  Taisto Kasurinen is a Finnish coal miner whose...
# 3  An episode in the life of Nikander, a garbage ...
# 4                                                  0
# 5  It's Ted the Bellhop's first night on the job....
# 6  While racing to a boxing match, Frank, Mike, J...
# 7  Princess Leia is captured and held hostage by ...
# 8  Nemo, an adventurous young clownfish, is unexp...
# 9  A man with a low IQ has accomplished great thi...
#
#                                              tagline    id_btc  \
# 0                                                NaN       NaN
# 1                                                NaN       NaN
# 2                                                NaN       NaN
# 3                                                NaN       NaN
# 4                              Beware Of Frost Bites       NaN
# 5  Twelve outrageous guests. Four scandalous requ...       NaN
# 6     Don't move. Don't whisper. Don't even breathe.       NaN
# 7       A long time ago in a galaxy far, far away...      10.0
# 8  There are 3.7 trillion fish in the ocean. They...  137697.0
# 9  The world will never be the same, once you've ...       NaN
#
#                   name_btc release_date  release_year      budget  ...  \
# 0                      NaN   1997-08-20          1997         0.0  ...
# 1                      NaN   2012-09-29          2012         0.0  ...
# 2                      NaN   1988-10-21          1988         0.0  ...
# 3                      NaN   1986-10-16          1986         0.0  ...
# 4                      NaN   2014-01-01          2014         0.0  ...
# 5                      NaN   1995-12-09          1995   4000000.0  ...
# 6                      NaN   1993-10-15          1993         0.0  ...
# 7     Star Wars Collection   1977-05-25          1977  11000000.0  ...
# 8  Finding Nemo Collection   2003-05-30          2003  94000000.0  ...
# 9                      NaN   1994-07-06          1994  55000000.0  ...
#
#    country_name  original_language languages_code           languages_name  \
# 0           NaN                  0             en                  English
# 1           NaN                  0             ja                      日本語
# 2           NaN                 fi         fi, de           suomi, Deutsch
# 3           NaN                 fi     en, fi, sv  English, suomi, svenska
# 4           NaN                  0             en                  English
# 5           NaN                 en             en                  English
# 6           NaN                 en             en                  English
# 7           NaN                 en             en                  English
# 8           NaN                 en             en                  English
# 9           NaN                 en             en                  English
#
#   runtime vote_average  popularity  vote_count    status  \
# 0   104.0          6.0    0.065736         1.0  Released
# 1    68.0          7.0    1.931659        12.0  Released
# 2    69.0          7.1    3.860491        44.0  Released
# 3    76.0          7.1    2.292110        35.0  Released
# 4    82.0          4.3    2.185485        22.0  Released
# 5    98.0          6.5    9.026586       539.0  Released
# 6   110.0          6.4    5.538671        79.0  Released
# 7   121.0          8.1   42.149697      6778.0  Released
# 8   100.0          7.6   25.497794      6292.0  Released
# 9   142.0          8.2   48.307194      8147.0  Released
#
#                                       direction_name
# 0                                                NaN
# 1                                                NaN
# 2                                     Aki Kaurismäki
# 3                                     Aki Kaurismäki
# 4                                                NaN
# 5  [Allison Anders, Alexandre Rockwell, Robert Ro...
# 6                                    Stephen Hopkins
# 7                                       George Lucas
# 8                                     Andrew Stanton
# 9                                    Robert Zemeckis
#
# [10 rows x 27 columns]

# %% [markdown]
# **7.** Se realiza la consulta del nombre de todas las variables del DataFrame.

# %%
columns= df_movies_crew.columns.tolist()
columns
# Out:
# ['Unnamed: 0',
#  'id',
#  'title',
#  'overview',
#  'tagline',
#  'id_btc',
#  'name_btc',
#  'release_date',
#  'release_year',
#  'budget',
#  'revenue',
#  'return',
#  'genres_id',
#  'genres_name',
#  'ption_companies_id',
#  'ption_companies_name',
#  'country_code',
#  'country_name',
#  'original_language',
#  'languages_code',
#  'languages_name',
#  'runtime',
#  'vote_average',
#  'popularity',
#  'vote_count',
#  'status',
#  'direction_name']

# %% [markdown]
# **8.** Se crea un nuevo DataFrame con las columnas deseadas

# %%
columns_newdf = ['id',
                'title',
                'direction_name',
                'release_date',
                'budget',
                'revenue',
                'return']
df_director = df_movies_crew[columns_newdf].copy()

# %% [markdown]
# + Se consulta las filas iniciales del nuevo DataFrame para falidar que la información este de acuerdo a lo esperado.

# %%
df_director.head(15)
# Out:
#     id                                title  \
# 0    0                         Midnight Man
# 1    1  Mardock Scramble: The Third Exhaust
# 2    2                                Ariel
# 3    3                  Shadows in Paradise
# 4    4                     Avalanche Sharks
# 5    5                           Four Rooms
# 6    6                       Judgment Night
# 7   11                            Star Wars
# 8   12                         Finding Nemo
# 9   13                         Forrest Gump
# 10  14                      American Beauty
# 11  15                         Citizen Kane
# 12  16                   Dancer in the Dark
# 13  17                             The Dark
# 14  18                    The Fifth Element
#
#                                        direction_name release_date  \
# 0                                                 NaN   1997-08-20
# 1                                                 NaN   2012-09-29
# 2                                      Aki Kaurismäki   1988-10-21
# 3                                      Aki Kaurismäki   1986-10-16
# 4                                                 NaN   2014-01-01
# 5   [Allison Anders, Alexandre Rockwell, Robert Ro...   1995-12-09
# 6                                     Stephen Hopkins   1993-10-15
# 7                                        George Lucas   1977-05-25
# 8                                      Andrew Stanton   2003-05-30
# 9                                     Robert Zemeckis   1994-07-06
# 10                                         Sam Mendes   1999-09-15
# 11                                       Orson Welles   1941-04-30
# 12                                     Lars von Trier   2000-05-17
# 13                                       John Fawcett   2006-01-26
# 14                                         Luc Besson   1997-05-07
#
#         budget      revenue  return
# 0          0.0          0.0    0.00
# 1          0.0          0.0    0.00
# 2          0.0          0.0    0.00
# 3          0.0          0.0    0.00
# 4          0.0          0.0    0.00
# 5    4000000.0    4300000.0    1.08
# 6          0.0   12136938.0    0.00
# 7   11000000.0  775398007.0   70.49
# 8   94000000.0  940335536.0   10.00
# 9   55000000.0  677945399.0   12.33
# 10  15000000.0  356296601.0   23.75
# 11    839727.0   23217674.0   27.65
# 12  12800000.0   40031879.0    3.13
# 13         0.0          0.0    0.00
# 14  90000000.0  263920180.0    2.93

# %% [markdown]
# **9.** Se cambia el formato a la columna **`release date`** la cual debe tener el formato **`AAAA-mm-dd`**.

# %%
df_director['release_date']=pd.to_datetime(df_director['release_date'])

# %% [markdown]
# **10.** Se consulta el detallado de la información del DataFrame para constatar los cambios en el formato de fecha.

# %%
df_director.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45349 entries, 0 to 45348
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              45349 non-null  int64
#  1   title           45349 non-null  object
#  2   direction_name  45253 non-null  object
#  3   release_date    45349 non-null  datetime64[ns]
#  4   budget          45349 non-null  float64
#  5   revenue         45349 non-null  float64
#  6   return          45349 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(2)
# memory usage: 2.8+ MB

# %% [markdown]
# **11.** Se cambian los nombres de las variables para efectos de mayor claridad al momento de la creación de las funciones para los **`endpoint`**.

# %%
new_names_columns = {'id': 'Id_Peliculas',
                    'title': 'Nombre_Pelicula',
                    'direction_name': 'Nombre_Director',
                    'release_date': 'Fecha_Estreno_Pelicula',
                    'budget': 'Presupuesto',
                    'revenue': 'Recaudacion_Total',
                    'return': 'Retorno_Inversion'}

df_director.rename(columns=new_names_columns, inplace=True)
df_director.head(20)
# Out:
#     Id_Peliculas                                    Nombre_Pelicula  \
# 0              0                                       Midnight Man
# 1              1                Mardock Scramble: The Third Exhaust
# 2              2                                              Ariel
# 3              3                                Shadows in Paradise
# 4              4                                   Avalanche Sharks
# 5              5                                         Four Rooms
# 6              6                                     Judgment Night
# 7             11                                          Star Wars
# 8             12                                       Finding Nemo
# 9             13                                       Forrest Gump
# 10            14                                    American Beauty
# 11            15                                       Citizen Kane
# 12            16                                 Dancer in the Dark
# 13            17                                           The Dark
# 14            18                                  The Fifth Element
# 15            19                                         Metropolis
# 16            20                                 My Life Without Me
# 17            21                                 The Endless Summer
# 18            22  Pirates of the Caribbean: The Curse of the Bla...
# 19            24                                  Kill Bill: Vol. 1
#
#                                       Nombre_Director Fecha_Estreno_Pelicula  \
# 0                                                 NaN             1997-08-20
# 1                                                 NaN             2012-09-29
# 2                                      Aki Kaurismäki             1988-10-21
# 3                                      Aki Kaurismäki             1986-10-16
# 4                                                 NaN             2014-01-01
# 5   [Allison Anders, Alexandre Rockwell, Robert Ro...             1995-12-09
# 6                                     Stephen Hopkins             1993-10-15
# 7                                        George Lucas             1977-05-25
# 8                                      Andrew Stanton             2003-05-30
# 9                                     Robert Zemeckis             1994-07-06
# 10                                         Sam Mendes             1999-09-15
# 11                                       Orson Welles             1941-04-30
# 12                                     Lars von Trier             2000-05-17
# 13                                       John Fawcett             2006-01-26
# 14                                         Luc Besson             1997-05-07
# 15                                         Fritz Lang             1927-01-10
# 16                                      Isabel Coixet             2003-03-07
# 17                                        Bruce Brown             1966-06-15
# 18                                     Gore Verbinski             2003-07-09
# 19                                  Quentin Tarantino             2003-10-10
#
#     Presupuesto  Recaudacion_Total  Retorno_Inversion
# 0           0.0                0.0               0.00
# 1           0.0                0.0               0.00
# 2           0.0                0.0               0.00
# 3           0.0                0.0               0.00
# 4           0.0                0.0               0.00
# 5     4000000.0          4300000.0               1.08
# 6           0.0         12136938.0               0.00
# 7    11000000.0        775398007.0              70.49
# 8    94000000.0        940335536.0              10.00
# 9    55000000.0        677945399.0              12.33
# 10   15000000.0        356296601.0              23.75
# 11     839727.0         23217674.0              27.65
# 12   12800000.0         40031879.0               3.13
# 13          0.0                0.0               0.00
# 14   90000000.0        263920180.0               2.93
# 15   92620000.0           650422.0               0.01
# 16          0.0          9726954.0               0.00
# 17          0.0                0.0               0.00
# 18  140000000.0        655011224.0               4.68
# 19   30000000.0        180949000.0               6.03

# %% [markdown]
# # <h1 align=left>**`Load`**</h1>

# %% [markdown]
# **12.** Teniendo lista la información con los datos deseados se procede con la creación del nuevo Dataset.

# %%
df_director.to_csv("..\Data\directors_dataset.csv")
